# %%
#Test of read_dataset function

ef read_dataset(dataset_path: str) -> pd.DataFrame: 
    #filename = input('Enter the file name including the .csv on the end:')
    #path = input('Enter the file path or where it\'s located on your computer :')
    dataset = pd.read_csv(filepath_or_buffer=dataset_path)
    return dataset

if __name__== "__main__":

    #print(describe)
    absolute_path= 'E:/Repos/capstone_project/capstone_project/data.csv'
    df = read_dataset(dataset_path=absolute_path)
    print(df.shape)

# %%
#Test of describe function

# Describe dataset = function
def describe(dataset_description: str) -> str:
    """ This function is to describe the dataset
    """
    print(dataset_description.describe()) 
    
if __name__== "__main__":

    #print(describe)
    absolute_path= 'E:/Repos/capstone_project/capstone_project/data.csv'
    df = read_dataset(dataset_path=absolute_path)
    file_description = describe(dataset_description=df)
    print(describe)

# %%
    
# Class 1 = Data Manipulation any below are members

class data_manipulation:
    def __init__(self, df: pd.DataFrame, column_name: str):
        self.df = df.copy()
        self.column_name = column_name
    
    def drop_missing_data(self, no_missing: data_manipulation) -> pd.DataFrame: 
        """Drops rows with missing values in the specified column.

        Args:
            column_name (str): The name of the column to drop missing values from.

        Returns: pd.DataFrame: The DataFrame with missing values dropped.
        """
        self.df = self.df.dropna(subset=[column_name])
        no_missing_dataset = {
        "column_name": no_missing.column_name,
        }
    return self.df 


or
class data_manipulation:
    def __init__(self, df: pd.DataFrame, column_name: str):
        self.df = df.copy()
        self.column_name = column_name
    
    def drop_missing_data(self, column_name: str) -> pd.DataFrame: 
        """Drops rows with missing values in the specified column.

        Args:
            column_name (str): The name of the column to drop missing values from.

        Returns: pd.DataFrame: The DataFrame with missing values dropped.
        """
        self.df = self.df.dropna(subset=[column_name])
        return self.df

or

class data_manipulation:
    def __init__(self, df: pd.DataFrame, column_name: str):
        self.df_raw = df
        self.df = df.copy()

    
    def drop_missing_data(self, column_name: str) -> pd.DataFrame: 
        """Drops rows with missing values in the specified column.

        Args:
            column_name (str): The name of the column to drop missing values from.

        Returns: pd.DataFrame: The DataFrame with missing values dropped.
        """
        self.df = self.df.dropna(subset=[column_name])
        return self.df
    
    def drop_column(self, column_name: str):
        self.df.drop(columns=column_name)
        return self.df
    
    def encoder_label(self, column_names)
        self.df.encoder(column_names)
        
        my_data_manipulation = DataManipulation(df=my_data)
        data_df = my_data_manipulation.drop_column(column_name="data")
        my_data_manipulation.encoder_label(column_name=["brand", "model"])
